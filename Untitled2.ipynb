# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904842-dotcom/NGUYEN-TUAN-PHUONG/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input())

tong = 0
for i in range(2, n + 1, 2):
    tong += i

print(tong)
# Out:
# 10
# 30

# %%
s = input().strip()
words = s.split()

word_count = len(words)
longest_word = max(words, key=len)

print(f"Words: {word_count}")
print(f"Longest word: {longest_word}")
# Out:
# lap trinh python co ban
# Words: 5
# Longest word: python

# %%
nums = list(map(int, input().split()))

unique_nums = sorted(set(nums))

second_largest = unique_nums[-2]

print(f"Sorted list: {unique_nums}")
print(f"Second largest: {second_largest}")
# Out:
# 5 1 3 5 2 3
# Sorted list: [1, 2, 3, 5]
# Second largest: 3

# %%
scores = list(map(float, input().split()))

valid_scores = [s for s in scores if 0 <= s <= 10]

average = sum(valid_scores) / len(valid_scores)
passed = len([s for s in valid_scores if s >= 5])

print(f"Average: {average}")
print(f"Passed: {passed}")
# Out:
# 7 8 11 -1 4 5
# Average: 6.0
# Passed: 3
